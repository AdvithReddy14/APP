# %% [markdown]
# <a href="https://colab.research.google.com/github/AdvithReddy14/APP/blob/main/Untitled20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-faf2c7bc-ce55-4503-a6b6-05be276bae3b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-faf2c7bc-ce55-4503-a6b6-05be276bae3b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('Weather Dataset.csv')

data.head(5)

data.info
# Out:
# <bound method DataFrame.info of                  Formatted Date        Summary Precip Type  Temperature (C)  \
# 0     2006-03-31 22:00:00+00:00  Partly Cloudy        rain         9.472222
# 1     2006-03-31 23:00:00+00:00  Partly Cloudy        rain         9.355556
# 2     2006-04-01 00:00:00+00:00  Mostly Cloudy        rain         9.377778
# 3     2006-04-01 01:00:00+00:00  Partly Cloudy        rain         8.288889
# 4     2006-04-01 02:00:00+00:00  Mostly Cloudy        rain         8.755556
# ...                         ...            ...         ...              ...
# 8755  2006-09-09 18:00:00+00:00  Partly Cloudy        rain        14.327778
# 8756  2006-09-09 19:00:00+00:00  Partly Cloudy        rain        12.661111
# 8757  2006-09-09 20:00:00+00:00  Partly Cloudy        rain        13.055556
# 8758  2006-09-09 21:00:00+00:00  Partly Cloudy        rain        12.050000
# 8759  2006-12-31 23:00:00+00:00          Foggy        snow        -0.650000
#
# ...

# %%
data.isnull().sum()
# Out:
# Formatted Date              0
# Summary                     0
# Precip Type                 0
# Temperature (C)             0
# Apparent Temperature (C)    0
# Humidity                    0
# Wind Speed (km/h)           0
# Wind Bearing (degrees)      0
# Visibility (km)             0
# Loud Cover                  0
# Pressure (millibars)        0
# Daily Summary               0
# month                       0
# dtype: int64

# %%
mean_temp = np.mean(data['Temperature (C)'])
print("Mean Temperature is :", mean_temp)
# Out:
# Mean Temperature is : 11.215224505327246

# %%
var_temp = np.var(data['Temperature (C)'])
print("Variance of Temperature is :", var_temp)
# Out:
# Variance of Temperature is : 92.10832938614996

# %%
standard_dev_temp = np.std(data['Temperature (C)'])
print("Standard Deviation of Temperature is :", standard_dev_temp)
# Out:
# Standard Deviation of Temperature is : 9.597308444879218

# %%
for i in range(1,13):
  month = data.loc[data["month"] == i]["Temperature (C)"]
  print("For month "+str(i))
  print("Mean temperature is "+ str(np.mean(month)))
  print("Standard deviation is "+ str(np.std(month))+"\n")
# Out:
# For month 1
# Mean temperature is -1.677942054958184
# Standard deviation is 4.571201837602936
#
# For month 2
# Mean temperature is -0.06539351851851853
# Standard deviation is 4.5619751209500565
#
# For month 3
# Mean temperature is 4.559274193548387
# Standard deviation is 5.716441576306105
#
# For month 4
# Mean temperature is 12.635030864197532
# Standard deviation is 4.770260724427961
#
# For month 5
# Mean temperature is 15.650731780167266
# Standard deviation is 4.744581723775079
#
# For month 6
# Mean temperature is 19.35462191358025
# Standard deviation is 6.647687763465947
#
# For month 7
# Mean temperature is 23.588664874551974
# Standard deviation is 5.348633953778177
#
# For month 8
# Mean temperature is 19.478726105137397
# Standard deviation is 4.751328709657937
#
# For month 9
# Mean temperature is 18.167731481481482
# Standard deviation is 4.813878512728091
#
# For month 10
# Mean temperature is 12.84475806451613
# Standard deviation is 5.97854812659291
#
# ...

# %%
plt.hist(data['Wind Bearing (degrees)'])
# Out:
# (array([1112.,  499.,  350.,  875., 1404.,  865.,  658.,  819., 1198.,
#          980.]),
#  array([  0. ,  35.9,  71.8, 107.7, 143.6, 179.5, 215.4, 251.3, 287.2,
#         323.1, 359. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data['Wind Speed (km/h)'])
# Out:
# (array([1873., 2410., 2345., 1198.,  468.,  281.,   95.,   58.,   24.,
#            8.]),
#  array([ 0.     ,  4.59333,  9.18666, 13.77999, 18.37332, 22.96665,
#         27.55998, 32.15331, 36.74664, 41.33997, 45.9333 ]),
#  <BarContainer object of 10 artists>)

# %%
bins_rating = np.arange(8, 10, 0.20)
plt.hist(data['Temperature (C)'], edgecolor="black", bins=bins_rating, color='g')
plt.ylabel("Frequency")
plt.xlabel("Temperature (C)")
plt.title("bins_rating")
# Out:
# Text(0.5, 1.0, 'bins_rating')
